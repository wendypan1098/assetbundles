# %%
# %sql
select * from assetbundles.information_schema.columns

# %%
spark.sql(f"select * from assetbundles.information_schema.columns")

# %%
dbutils.widgets.text("catalogs_name", "")

# %%
catalogs_name = dbutils.widgets.get("catalogs_name")

# %%
df = spark.sql(f"select * from {catalogs_name}.information_schema.columns")
display(df)
